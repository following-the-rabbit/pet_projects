# %%
import requests

# Example loan application
application = {
    " Destination Port":80,
    " Flow Duration":98978724,
    " Total Fwd Packets":5,
    " Total Backward Packets":8,
    "Total Length of Fwd Packets":380,
    " Total Length of Bwd Packets":11595,
    " Fwd Packet Length Max":368,
    " Fwd Packet Length Min":0,
    " Fwd Packet Length Mean":76,
    " Fwd Packet Length Std":163.2,
    "Bwd Packet Length Max":4344,
    " Bwd Packet Length Min":0,
    " Bwd Packet Length Mean":1449,
    " Bwd Packet Length Std":1729,
    "Flow Bytes/s":120.9855969,
    " Flow Packets/s":0.131341358,
    " Flow IAT Mean":8248227,
    " Flow IAT Std":28500000,
    " Flow IAT Max":98800000,
    " Flow IAT Min":1,
    "Fwd IAT Total":98800000,
    " Fwd IAT Mean":24700000,
    " Fwd IAT Std":49400000,
    " Fwd IAT Max":98800000,
    " Fwd IAT Min":4,
    "Bwd IAT Total":99000000,
    " Bwd IAT Mean":14100000,
    " Bwd IAT Std":37300000,
    " Bwd IAT Max":98800000,
    " Bwd IAT Min":15,
    "Fwd PSH Flags":0,
    " Bwd PSH Flags":0,
    " Fwd URG Flags":0,
    " Bwd URG Flags":0,
    " Fwd Header Length":144,
    " Bwd Header Length":264,
    "Fwd Packets/s":0.05051591,
    " Bwd Packets/s":0.08082545,
    " Min Packet Length":0,
    " Max Packet Length":4344,
    " Packet Length Mean":856,
    " Packet Length Std":1458,
    " Packet Length Variance":2124858.2,
    "FIN Flag Count":1,
    " SYN Flag Count":0,
    " RST Flag Count":0,
    " PSH Flag Count":0,
    " ACK Flag Count":0,
    " URG Flag Count":0,
    " CWE Flag Count":0,
    " ECE Flag Count":0,
    " Down/Up Ratio":1,
    " Average Packet Size":921.5,
    " Avg Fwd Segment Size":76,    
    " Avg Bwd Segment Size":1449,
    " Fwd Header Length.1":144,
    "Fwd Avg Bytes/Bulk":0,
    " Fwd Avg Packets/Bulk":0,
    " Fwd Avg Bulk Rate":0,
    " Bwd Avg Bytes/Bulk":0,
    " Bwd Avg Packets/Bulk":0,
    "Bwd Avg Bulk Rate":0,
    "Subflow Fwd Packets":5,
    " Subflow Fwd Bytes": 380,
    " Subflow Bwd Packets":8,
    " Subflow Bwd Bytes":11595,
    "Init_Win_bytes_forward":0,
    "Init_Win_bytes_backward":235,
    " act_data_pkt_fwd":2,
    " min_seg_size_forward":20,
    "Active Mean":13804,
    " Active Std":0,
    " Active Max":13804,
    " Active Min":13804,
    "Idle Mean":98800000,
    " Idle Std":0,
    " Idle Max":98800000,
    " Idle Min":98800000,  
}

# Location of my server
url = "http://0.0.0.0:8989/predict"

# Send request
resp = requests.post(url, json=application)

# Print result
print(resp.json())
# Out:
# {'default': 'DoS Hulk'}

# %% [raw]
# docker build -t default-service-my:v01 .
#
# docker run -it --rm -p 8989:8989 default-service-my:v01
#
# docker stop $(docker ps -a -q)
